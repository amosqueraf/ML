# %% [markdown]
# ## Machine Learning
# #### MIIA 4200-01 (2019-I) - Ejercicio 2
#
# <p>Profesor: Alejandro Correa</p>
# <p>Estudiante: Oscar Andrés Mosquera </p>
#
# * Estructuras de Control
#     + Análisis de Texto

# %% [markdown]
# # Exercise 2.1
#
# Complete the function that calculates the similarities of all texts in the dataframe

# %%
import pandas as pd

archivo="E2-Data.csv"
data2=pd.read_csv(archivo, low_memory=False)

# %%
data = pd.DataFrame(columns=['Text', 'Undergrad', 'Semester', 'Age', 'Company'])

# %%
# Example dataset
data.loc[0] = ['Uno de los criterios más importantes en la selección de un lenguaje de programación, es el desempeño de éste en el procesamiento de datos, sobre todo cuando es usado en el  análisis de grandes volúmenes de información. Por esta razón, para el presente taller he implementado un ejercicio en el que se compara el tiempo de cargue de un archivo texto con once millones de registros a una estructura tipo dataframe en lenguaje R, con el tiempo de cargue del mismo archivo a una estructura tipo dataframe en lenguaje Python, usando la librería PANDAS (Python Data Analysis Library). A pesar de realizar el ejercicio en la misma plataforma computacional (PC Toshiba, procesador Intel Core I7 con 12 Gb de memoria RAM), se evidencia una gran diferencia en el tiempo de cargue entre los dos lenguajes, observando que el tiempo promedio de cargue en R fue de 65 segundos, mientras que el tiempo promedio de cargue en Python fue de 12 segundos. No obstante, los resultados anteriores al tener el dataframe creado en cada uno de los lenguajes evaluados y comparar los tiempos de procesamiento con operaciones básicas de estadística descriptiva (función describe en Python vs summary en R), se encontró que Python arrojó los resultados en 6 segundos mientras que R arrojó los resultados en 0.7 segundos. En conclusión, el anterior experimento no es determinante al momento de decidir entre uno de estos dos lenguajes, toda vez que es necesario complementar con otros criterios como son el soporte, las librerías existentes y editores de código disponibles, criterio en el que Python ofrece ventajas en su arquitectura al ser un lenguaje de propósito general en el que se pueden crear proyectos robustos no solo de analítica de datos si no también aplicaciones integradas, desarrollo de juegos, etc.',
               'Ingeniería de sistemas', 4, 46, 'ETB']
data.loc[1] = ['El duelo entre Data Engineer vs Data Scientist se puede simplificar a su principal foco, mientras los Data Scientist se centran en el análisis de los datos generados, los Data Engineer son los encargados de disponer la infraestructura y arquitectura para generarlos. Si bien comparten algunas competencias, el Data Scientist tiene habilidades específicas y fuertes en matemáticas y estadísticas que les permiten crear análisis avanzados mediante la aplicación de diferentes modelos, especialmente de machine learning e inteligencia artificial. En contraste el Data Engineer es hábil en el campo de la programación y la creación de soluciones de software. En este sentido se podría afirmar que el Engineer es el rol responsable de la preparación de los datos, para ser analizados por el Scientist. Sin embargo, es importante que estos dos roles cohabiten y es deseable que un profesional sea integral compartiendo habilidades de ambos lados de la orilla. Mientras un Data Scientist debe entender los problemas de negocio para realizar las preguntas correctas, es ideal que conozca de donde provienen los datos a ser explorados y tenga idea de cómo fueron obtenidos. En esta misma línea el Data Engineer debería ser capaz de entender esta misma dinámica, con el objeto de optimizar la infraestructura necesaria para disponer la data a ser explotada.  Se espera que el Data Scientist de línea sobre las diferentes formas de visualización e interpretación de los resultados, y que el Data Engineer disponga las estructuras, accesos y diferentes recursos para acceder a los datos, así como que también se encargue de su mantenimiento y eficiencia dentro del gran ecosistema de los datos. Se podría sugerir que en el inicio de un proyecto de análisis de datos los Data Engineer deben ser aquellos que construyan las bases y desarrollen la infraestructura para que los Data Scientist en una segunda etapa, realicen los análisis de acuerdo a la dinámica del negocio.',
               'Ingeniería de sistemas', 2, 31, 'Uniminuto']
data.loc[2] = ['Dos de las principales razones por las que a partir de su nacimiento en 1991 haya tenido tanta acogida como lenguaje de programación es porque en primera instancia es un lenguaje de alto nivel muy fácil de usar y la segunda es que es de código libre. Ahora bien, lenguajes como R también poseen estas características, entonces que es lo que realmente hace a Python tan interesante. Python, es un lenguaje multipropósito, que no solo te va a permitir hacer proyectos de Datascience (como también lo hace R) sino que te va a permitir llevar a otro nivel el proyecto involucrando al creación de API´s y hasta softwares para la puesta en marcha de dicho proyecto, y es justo esta versatilidad de Python, aparte de las bondades que ofrece ser un lenguaje orientado a objetos y multiplataforma, la que le da mayor desenvolvimiento, practicidad y acogida en el mundo no solo de la analítica sino en general de todo el mundo tecnológico. Por otro lado, y no menos importante, con al creciente demanda de plataformas de BigData, llámese Hadoop, Python si que lleva la delantera ya que naturalmente puede programarse para procesarse en ambiente distribuido en todas sus vertientes, mientras que R tiene ciertas limitaciones ya que solo la librería sparklyr permite llevar a cabo este tipo de tareas de procesamiento en ambientes distribuido.',
               'Economía', 2, 39, 'Bancamía']
data.loc[3] = ['Differences of a Data Scientist and a Data Engineer Las diferencias entre un científico de datos y un ingeniero de datos radican en el rol que juega cada uno a la hora de interactuar con los datos. Por un lado, los ingenieros de datos se encargan de la construcción, mantenimiento y ajustes de la infraestructura tecnológica en la cual se encuentran los datos. Mientras que los científicos de datos hacen uso de esa infraestructura, no solo para acceder a los datos, sino para poner en práctica modelos matemáticos avanzados para el análisis estadístico. Los científicos de datos interactúan constantemente con la infraestructura creada por los ingenieros de datos, sin embargo, no son responsables de la continua construcción ni mantenimiento de la infraestructura. Por el contrario, son quienes demandan los desarrollos y ajustes a los ingenieros. Tanto los científicos como los ingenieros de datos dependen el uno del otro, en la medida en que, sin la infraestructura y herramientas adecuadas para el análisis de los datos, los científicos no podrían realizar su trabajo ni avanzar en métodos ni modelos cada vez más sofisticados. Los mismo sucede con los ingenieros, quienes, sin la demanda por parte de los científicos sobre desarrollos en las herramientas adecuadas, por ejemplo, en lenguajes de programación, capacidad en almacenamiento y procesamiento o visualización de los datos, sería muy complejo y poco eficiente avanzar en la creación, mantenimiento y adecuación. De tal forma, es evidente que puede darse cierta confusión a la hora de diferenciar el papel de los científicos de datos y los ingenieros de datos. Sin embargo, el papel que cada uno juega en la visión de negocio de las organizaciones, define el campo de acción y los límites hasta donde interactúa cada uno con los datos.',
               'Administración de empresas', 2, 25, 'ETB']

# %%
data
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Text</th>
#       <th>Undergrad</th>
#       <th>Semester</th>
#       <th>Age</th>
#       <th>Company</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Uno de los criterios más importantes en la sel...</td>
#       <td>Ingeniería de sistemas</td>
#       <td>4</td>
#       <td>46</td>
#       <td>ETB</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>El duelo entre Data Engineer vs Data Scientist...</td>
#       <td>Ingeniería de sistemas</td>
#       <td>2</td>
#       <td>31</td>
#       <td>Uniminuto</td>
#     </tr>
#     <tr>
#       <th>2</th>
# ...

# %%
lista1=set(data.loc[0,'Text'].split())
lista2=set(data.loc[1,'Text'].split())
lista3=set(data.loc[2,'Text'].split())
lista4=set(data.loc[3,'Text'].split())

 
final= lista1 & lista2 & lista3 & lista4
if len(final) > 0 :
    print("hay {} elementos coincidentes".format(len(final)))
    print(final)
else:
    print("no hay repeticiones")
# Out:
# hay 14 elementos coincidentes
# {'que', 'a', 'y', 'su', 'en', 'para', 'un', 'las', 'la', 'es', 'con', 'como', 'el', 'de'}

# %%
import numpy as np

c=0
for i in range(1,len(data)):
    if data.loc[i,'Text']==data.loc[i-1,'Text']:
        c=c+1
    else:
        print("hay",c,"coincidencias")
    #c = int(np.all(np.array(a) == np.array(b)))
# Out:
# hay 0 coincidencias
# hay 0 coincidencias
# hay 0 coincidencias

# %%
def similarity(data):

    results = pd.DataFrame(0, index=data.index, columns=data.index)

    # your code in here
    n = len(data(data))
    c = 0
    for i in data:
        for j in i:
            if c < n:
                c += 1
        results =  i+ j
    assert results.shape == (data.shape[0], data.shape[0])
    return results
#similarity(data)

# %% [markdown]
# # Exercise 2.2
#
# Calculate descriptive statistics of the dataset
#
# - Pivot tables analyzing companies, universities, age and master semester.

# %%
data2
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Text</th>
#       <th>Undergrad</th>
#       <th>Semester</th>
#       <th>Age</th>
#       <th>Company</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Uno de los criterios mas importantes en la sel...</td>
#       <td>Ingenieria de sistemas</td>
#       <td>4</td>
#       <td>46</td>
#       <td>ETB</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>Actualmente para las empresas los cientificos ...</td>
#       <td>Administracion de empresas</td>
#       <td>2</td>
#       <td>38</td>
#       <td>Interactivo contact center sa</td>
#     </tr>
#     <tr>
# ...

# %%
Company = data2.pivot_table(values='Text', index=['Company'], aggfunc='count')
Company
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Text</th>
#     </tr>
#     <tr>
#       <th>Company</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Alcaldia de Santiago de Cali</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Aon Benbenfield corredores de reaseguros</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Aseguradora solidaria de Colombia</th>
#       <td>0</td>
#     </tr>
#     <tr>
#       <th>Avianca</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Bancamia</th>
#       <td>1</td>
#     </tr>
#     <tr>
#       <th>Banco caja social</th>
#       <td>1</td>
#     </tr>
#     <tr>
# ...

# %%
Company.plot(kind='bar', figsize=(15,5))

# %%
Undergrad = data2.pivot_table(values='Text', index=['Undergrad'], columns=['Semester'], aggfunc='count')
Undergrad.fillna(0, inplace=True)
Undergrad.plot(kind='bar', figsize=(15,5))

# %%
Undergrad.plot(kind='bar', color='rby',figsize=(15,5))

# %%
Age = data2.pivot_table(values='Age', index=['Semester'], aggfunc='count')
Age
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Age</th>
#     </tr>
#     <tr>
#       <th>Semester</th>
#       <th></th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>2</th>
#       <td>39</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>5</td>
#     </tr>
#   </tbody>
# </table>
# </div>
